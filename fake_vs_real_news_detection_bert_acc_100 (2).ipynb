# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/IBM DS.zip"
# Out:
# Archive:  /content/drive/MyDrive/IBM DS.zip
#   inflating: Fake.csv
#   inflating: True.csv

# %%
# %pip install transformers datasets --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 45.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 32.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 87.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.9 MB/s eta 0:00:00

# %%
import time
import numpy as np
import pandas as pd
import nltk
import string
import tensorflow as tf
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
nltk.download('stopwords')
import plotly.express as px
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
CLASS_NAMES = ["Fake", "Real"]
MAPPING_DICT = {
    "Fake":0,
    "Real":1
}
model_name = "BERTFakeNewsDetector"
MODEL_CALLBACKS = [ModelCheckpoint(model_name, save_best_only=True)]

# %%
fake_news_filepath = "/content/Fake.csv"
real_news_filepath = "/content/True.csv"

# %%
fake_df = pd.read_csv(fake_news_filepath)
real_df = pd.read_csv(real_news_filepath)

# %%
fake_df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
real_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
real_df["Label"] = "Real"
fake_df["Label"] = "Fake"

# %%
df = pd.concat([fake_df, real_df])
df.reset_index()
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date Label
# 0  December 31, 2017  Fake
# 1  December 31, 2017  Fake
# 2  December 30, 2017  Fake
# 3  December 29, 2017  Fake
# 4  December 25, 2017  Fake

# %%
print(f"Dataset Size: {len(df)}")
# Out:
# Dataset Size: 44898

# %%
data = df.sample(1000).drop(columns=["title", "subject", "date"])
data.Label = data.Label.map(MAPPING_DICT)
data.sample(10)
# Out:
#                                                     text  Label
# 5013   WASHINGTON (Reuters) - House of Representative...      1
# 21017  Will the Democrats ultimately choose a Marxist...      0
# 9512   NEW YORK (Reuters) - The race to succeed Repub...      1
# 6577   What would you do if you had a known video voy...      0
# 6797   BATON ROUGE, La. (Reuters) - U.S. President-el...      1
# 16698  LUBUMBASHI, Democratic Republic of Congo (Reut...      1
# 2577   KABUL (Reuters) - (This version of the July 23...      1
# 5500   The plot is definitely thickening when it come...      0
# 1533   When getting to the truth behind Donald Trump ...      0
# 23467  21st Century Wire says So far, after nearly 20...      0

# %%
class_dis = px.histogram(
    data_frame = df,
    y = "Label",
    color = "Label",
    title = "Fake & Real Samples Distribution",
    text_auto=True
    )
class_dis.update_layout(showlegend=False)
class_dis.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4fb5c557-a2a5-420a-bfa0-916c0f5a87ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fb5c557-a2a5-420a-bfa0-916c0f5a87ec")) {                    Plotly.newPlot(                        "4fb5c557-a2a5-420a-bfa0-916c0f5a87ec",                        [{"alignmentgroup":"True","bingroup":"y","hovertemplate":"Label=%{y}\u003cbr\u003ecount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fake","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fake","offsetgroup":"Fake","orientation":"h","showlegend":true,"texttemplate":"%{value}","xaxis":"x","y":["Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake","Fake"," ...

# %%
subject_dis = px.histogram(
    data_frame = df,
    x = "subject",
    color = "subject",
    facet_col = "Label",
    title = "Fake & Real Subject Distribution",
    text_auto=True
    )
subject_dis.update_layout(showlegend=False)
subject_dis.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d29abdd9-1eed-460e-ae81-bb3fe946f3d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d29abdd9-1eed-460e-ae81-bb3fe946f3d0")) {                    Plotly.newPlot(                        "d29abdd9-1eed-460e-ae81-bb3fe946f3d0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"subject=%{x}\u003cbr\u003eLabel=Fake\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"News","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"News","offsetgroup":"News","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News"," ...

# %%
list(filter(lambda x: len(x)>20, df.date.unique()))
# Out:
# ['https://100percentfedup.com/served-roy-moore-vietnamletter-veteran-sets-record-straight-honorable-decent-respectable-patriotic-commander-soldier/',
#  'https://100percentfedup.com/video-hillary-asked-about-trump-i-just-want-to-eat-some-pie/',
#  'https://100percentfedup.com/12-yr-old-black-conservative-whose-video-to-obama-went-viral-do-you-really-love-america-receives-death-threats-from-left/',
#  'https://fedup.wpengine.com/wp-content/uploads/2015/04/hillarystreetart.jpg',
#  'https://fedup.wpengine.com/wp-content/uploads/2015/04/entitled.jpg',
#  'MSNBC HOST Rudely Assumes Steel Worker Would Never Let His Son Follow in His Footsteps…He Couldn’t Be More Wrong [Video]']

# %%
df = df[df.date.map(lambda x: len(x)) <= 20]
df.date = pd.to_datetime(df.date, exact=True)
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject       date Label
# 0  Donald Trump just couldn t wish all Americans ...    News 2017-12-31  Fake
# 1  House Intelligence Committee Chairman Devin Nu...    News 2017-12-31  Fake
# 2  On Friday, it was revealed that former Milwauk...    News 2017-12-30  Fake
# 3  On Christmas day, Donald Trump announced that ...    News 2017-12-29  Fake
# 4  Pope Francis used his annual Christmas Day mes...    News 2017-12-25  Fake

# %%
label_date_hist = px.histogram(
    data_frame = df,
    x = 'date',
    color = "Label",
)
label_date_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="15eb1fcc-aeee-4391-a50e-7bf7bf63b526" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15eb1fcc-aeee-4391-a50e-7bf7bf63b526")) {                    Plotly.newPlot(                        "15eb1fcc-aeee-4391-a50e-7bf7bf63b526",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Label=Fake\u003cbr\u003edate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fake","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fake","offsetgroup":"Fake","orientation":"v","showlegend":true,"x":["2017-12-31T00:00:00","2017-12-31T00:00:00","2017-12-30T00:00:00","2017-12-29T00:00:00","2017-12-25T00:00:00","2017-12-25T00:00:00","2017-12-23T00:00:00","2017-12-23T00:00:00","2017-12-22T00:00:00","2017-12-21T00:00:00","2017-12-21T00:00:00","2017-12-21T00:00:00","2017-12-21T00:00:00","2017-12-20T00:00:00","2017-12-20T00:00:00","2017-12-20T00:00:00","2017-12-19T00:00:00","2017-12-17T00:00:00","2017-12-17T00:00:00","2017-12-16T00:00:00","2017-12-16T00:00:00","2017-12-13T00:00:00","2017-12-12T00:00:00","2017-12-12T00:00:00","2017-12-12T00:00:00","2017-12-12T00:00:00","2017-12-11T00:00:00","2017-12-10T00:00:00","2017-12-09T00:00:00","2017-12-07T00:00:00","2017-12-07T00:00:00","2017-12-07T00:00:00","2017-12-06T00:00:00","2017-12-06T00:00:00","2017-12-06T00:00:00","2017-12-05T00:00:00","2017-12-05T00:00:00","2017-12-05T00:00:00","2017-12-05T00:00:00","2017-12-04T00:00:00","2017-12-03T00:00:00","2017-12-03T00:00:00","2017-12-02T00:00:00","2017-12-02T00:00:00","2017-12-01T00:00
:00","2017-11-30T00:00:00","2017-11-29T00:00:00","2017-11-29T00:00:00","2017-11-29T00:00:00","2017-11-29T00:00:00","2017-11-28T00:00:00","2017-11-28T00:00:00","2017-11-28T00:00:00","2017-11-28T00:00:00","2017-11-27T00:00:00","2017-11-27T00:00:00","2017-11-27T00:00:00","2017-11-27T00:00:00","2017-11-26T00:00:00","2017-11-26T00:00:00","2017-11-25T00:00:00","2017-11-25T00:00:00","2017-11-25T00:00:00","2017-11-25T00:00:00","2017-11-24T00:00:00","2017-11-24T00:00:00","2017-11-23T00:00:00","2017-11-23T00:00:00","2017-11-22T00:00:00","2017-11-22T00:00:00","2017-11-22T00:00:00","2017-11-21T00:00:00","2017-11-21T00:00:00","2017-11-21T00:00:00","2017-11-20T00:00:00","2017-11-19T00:00:00","2017-11-18T00:00:00","2017-11-18T00:00:00","2017-11-17T00:00:00","2017-11-17T00:00:00","2017-11-17T00:00:00","2017-11-17T00:00:00","2017-11-16T00:00:00","2017-11-16T00:00:00","2017-11-16T00:00:00","2017-11-16T00:00:00","2017-11-15T00:00:00","2017-11-15T00:00:00","2017-11-15T00:00:00","2017-11-15T00:00:00","2017-11-14T00:00:00","2017-11-14T00:00:00","2017-11-13T00:00:00","2017-11-13T00:00:00","2017-11-13T00:00:00","2017-11-13T00:00:00","2017-11-13T00:00:00","2017-11-12T00:00:00","2017-11-11T00:00:00","2017-11-11T00:00:00","2017-11-11T00:00:00","2017-11-11T00:00:00","2017-11-10T00:00:00","2017-11-09T00:00:00","2017-11-09T00:00:00","2017-11-09T00:00:00","2017-11-09T00:00:00","2017-11-08T00:00:00","2017-11-08T00:00:00","2017-11-08T00:00:00","2017-11-08T00:00:00","2017-11-08T00:00:00","2017-11-08T00:00:00","2017-11-08T00:00:00","2017-11-07T00:00:00","2017-11-07T00:00:00","2017-11-07T00:00:00","2017-11-07T00:00:00","2017-11-07T00:00:00","2017-11-07T00:00:00","2017-11-07T00:00:00","2017-11-06T00:00:00","2017-11-06T00:00:00","2017-11-06T00:00:00","2017-11-06T00:00:00","2017-11-06T00:00:00","2017-11-06T00:00:00","2017-11-06T00:00:00","2017-11-05T00:00:00","2017-11-05T00:00:00","2017-11-05T00:00:00","2017-11-05T00:00:00","2017-11-05T00:00:00","2017-11-04T00:00:00","2017-11-04T00:00:00","2017-11-04T00:00:00","2017-11-04T00:00:00","2017 ...

# %%
stop_words = set(stopwords.words('english'))
def text_processing(text):
    words = text.lower().split()
    filtered_words = [word for word in words if word not in stop_words]
    clean_text = ' '.join(filtered_words)
    clean_text = clean_text.translate(str.maketrans('', '', string.punctuation)).strip()
    return clean_text

# %%
X = data.text.apply(text_processing).to_numpy()
Y = data.Label.to_numpy().astype('float32').reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    X, Y,
    train_size=0.9,
    test_size=0.1,
    stratify=Y,
    random_state=42
)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_train, y_train,
    train_size=0.9,
    test_size=0.1,
    stratify=y_train,
    random_state=42
)

# %%
bert_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(
    bert_name,
    padding = "max_length",
    do_lower_case = True,
    add_special_tokens = True,
)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
X_train_encoded = tokenizer(
    X_train.tolist(),
    padding = True,
    truncation = True,
    return_tensors = "tf"
).input_ids

X_valid_encoded = tokenizer(
    X_valid.tolist(),
    padding = True,
    truncation = True,
    return_tensors = "tf"
).input_ids

X_test_encoded = tokenizer(
    X_test.tolist(),
    padding = True,
    truncation = True,
    return_tensors = "tf"
).input_ids

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train_encoded, y_train)).shuffle(len(X_train)).batch(8).prefetch(tf.data.AUTOTUNE)
valid_ds = tf.data.Dataset.from_tensor_slices((X_valid_encoded, y_valid)).shuffle(len(X_valid)).batch(8).prefetch(tf.data.AUTOTUNE)
test_ds  = tf.data.Dataset.from_tensor_slices((X_test_encoded, y_test)).shuffle(len(X_test)).batch(8).prefetch(tf.data.AUTOTUNE)

# %%
bert_model = TFAutoModelForSequenceClassification.from_pretrained(bert_name, num_labels = 1)
# Out:
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
bert_model.compile(
    optimizer = Adam(learning_rate = 1e-5),
    metrics = [
        tf.keras.metrics.BinaryAccuracy(name="Accuracy"),
        tf.keras.metrics.Precision(name="Precision"),
        tf.keras.metrics.Recall(name="Recall"),
    ]
)

model_history = bert_model.fit(
    train_ds,
    validation_data = valid_ds,
    epochs = 5,
    batch_size = 16,
    callbacks = MODEL_CALLBACKS
)

model_history = pd.DataFrame(model_history.history)
# Out:
# Epoch 1/5
# 102/102 [==============================] - 198s 1s/step - loss: 0.1652 - Accuracy: 0.7580 - Precision: 0.7929 - Recall: 0.6802 - val_loss: 0.0611 - val_Accuracy: 0.9000 - val_Precision: 0.8302 - val_Recall: 1.0000
# Epoch 2/5
# 102/102 [==============================] - 150s 1s/step - loss: 0.0233 - Accuracy: 0.9840 - Precision: 0.9847 - Recall: 0.9822 - val_loss: 0.0094 - val_Accuracy: 0.9889 - val_Precision: 1.0000 - val_Recall: 0.9773
# Epoch 3/5
# 102/102 [==============================] - 142s 1s/step - loss: 0.0118 - Accuracy: 0.9926 - Precision: 0.9924 - Recall: 0.9924 - val_loss: 0.0011 - val_Accuracy: 1.0000 - val_Precision: 1.0000 - val_Recall: 1.0000
# Epoch 4/5
# 102/102 [==============================] - 102s 1s/step - loss: 0.0045 - Accuracy: 0.9988 - Precision: 0.9975 - Recall: 1.0000 - val_loss: 0.0042 - val_Accuracy: 1.0000 - val_Precision: 1.0000 - val_Recall: 1.0000
# Epoch 5/5
# 102/102 [==============================] - 140s 1s/step - loss: 0.0031 - Accuracy: 1.0000 - Precision: 1.0000 - Recall: 1.0000 - val_loss: 6.5147e-04 - val_Accuracy: 1.0000 - val_Precision: 1.0000 - val_Recall: 1.0000

# %%
bert_model.save(model_name)

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots
fig = make_subplots(rows=2, cols=2, subplot_titles=("Loss", "Accuracy", "Precision", "Recall"))
fig.add_trace(go.Scatter(y=model_history['loss'], mode='lines', name='Training Loss'), row=1, col=1)
fig.add_trace(go.Scatter(y=model_history['val_loss'], mode='lines', name='Validation Loss'), row=1, col=1)
fig.add_trace(go.Scatter(y=model_history['Accuracy'], mode='lines', name='Training Accuracy'), row=1, col=2)
fig.add_trace(go.Scatter(y=model_history['val_Accuracy'], mode='lines', name='Validation Accuracy'), row=1, col=2)
fig.add_trace(go.Scatter(y=model_history['Precision'], mode='lines', name='Training Precision'), row=2, col=1)
fig.add_trace(go.Scatter(y=model_history['val_Precision'], mode='lines', name='Validation Precision'), row=2, col=1)
fig.add_trace(go.Scatter(y=model_history['Recall'], mode='lines', name='Training Recall'), row=2, col=2)
fig.add_trace(go.Scatter(y=model_history['val_Recall'], mode='lines', name='Validation Recall'), row=2, col=2)
fig.update_layout(
    title='Model Training History',
    xaxis_title='Epoch',
    yaxis_title='Metric Value',
    showlegend=False,
)
fig.update_xaxes(title_text='Epoch', row=1, col=1)
fig.update_xaxes(title_text='Epoch', row=1, col=2)
fig.update_xaxes(title_text='Epoch', row=2, col=1)
fig.update_xaxes(title_text='Epoch', row=2, col=2)
fig.update_yaxes(title_text='Loss', row=1, col=1)
fig.update_yaxes(title_text='Accuracy', row=1, col=2)
fig.update_yaxes(title_text='Precision', row=2, col=1)
fig.update_yaxes(title_text='Recall', row=2, col=2)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3e5af7f4-7916-438e-b712-daa31c02c6d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e5af7f4-7916-438e-b712-daa31c02c6d0")) {                    Plotly.newPlot(                        "3e5af7f4-7916-438e-b712-daa31c02c6d0",                        [{"mode":"lines","name":"Training Loss","y":[0.16517850756645203,0.023299960419535637,0.011849358677864075,0.004451208747923374,0.0031288755126297474],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines","name":"Validation Loss","y":[0.06109597906470299,0.009357225149869919,0.001064812415279448,0.004249156452715397,0.0006514739361591637],"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines","name":"Training Accuracy","y":[0.7580246925354004,0.9839506149291992,0.9925925731658936,0.9987654089927673,1.0],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"lines","name":"Validation Accuracy","y":[0.8999999761581421,0.9888888597488403,1.0,1.0,1.0],"type":"scatter","xaxis":"x2","yaxis":"y2"},{"mode":"lines","name":"Training Precision","y":[0.7928994297981262,0.9847328066825867,0.9923858046531677,0.9974683523178101,1.0],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines","name":"Validation Precision","y":[0.8301886916160583,1.0,1.0,1.0,1.0],"type":"scatter","xaxis":"x3","yaxis":"y3"},{"mode":"lines","name":"Training Recall","y":[0.6802030205726624,0.9822335243225098,0.9923858046531677,1.0,1.0],"type":"scatter","xaxis":"x4","yaxis":"y4"},{"mode":"lines","name":"Validation Recall","y":[1.0,0.9772727489471436,1.0,1.0,1.0],"type":"scatter","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks": ...

# %%
test_loss, test_acc, test_precision, test_recall = bert_model.evaluate(test_ds, verbose = 0)

print(f"Test Loss      : {test_loss}")
print(f"Test Accuracy  : {test_acc}")
print(f"Test Precision : {test_precision}")
print(f"Test Recall    : {test_recall}")
# Out:
# Test Loss      : 0.0004772508982568979
# Test Accuracy  : 1.0
# Test Precision : 1.0
# Test Recall    : 1.0

# %%
def predict_text(text, model):
    tokens = tokenizer(text, return_tensors = 'tf', padding="max_length", truncation=True).input_ids
    return np.abs(np.round(model.predict(tokens, verbose = 0).logits))

# %%
import textwrap

# Your code here
for _ in range(5):
    index = np.random.randint(len(X_test))

    text = X_test[index]
    true = y_test[index]
    model_pred = predict_text(text, model=bert_model)[0]

    # Wrap the text with a maximum width
    wrapped_text = textwrap.fill(text, width=150)  # You can adjust the width as needed

    # Print the wrapped text
    print(f"ORIGINAL TEXT:\n\n{wrapped_text}\n\nTRUE: {CLASS_NAMES[int(true)]}\tPREDICTED: {CLASS_NAMES[int(model_pred)]}\n{'-'*100}\n")
# Out:
# ORIGINAL TEXT:
#
# donald trump seriously stupidconsidering sexual assault allegations him fact wants bang daughter fact hit teen girls talked dating girl tenyears old
# one would think trump would know better bring girl stage one ralliesbut exactly monday night invited child podium trump picked up told beautiful tried
# kiss repeatedly including lips girl clearly appreciate see face tries avoid trump lips runs back parentshere video via youtubethe optics absolutely
# terrible trump done year ago probably much story three weeks election day donald trump embroiled mountain sexual assault allegations still
# experiencing fallout comments groping women waiting kiss women considers beautiful apparently disgusting personal policy includes little girls tooof
# course trump trying kiss little girl horrified america let trump know twitterabout gross video trump trying kiss little girl will even try hug
# daughter feeling it bearded tombstoner beardedstoner october 18 2016that right children let creepy men like trump force kiss them good job tonight via
# goangelo pictwittercom7uxzme2okh riotwomenn riotwomennn october 18 2016given know trump find gif little girl pulling away kiss funny like all jessica
# valenti jessicavalenti october 18 2016i admit ready see trump trying kiss little black girl mouth hell someone else child jamil smith jamilsmith
# october 18 2016this extremely painful watch poor girl uncomfortable trump disgusting perverted man httpstcofzjiw8pxng izzy galvez iglvzx october 18
# 2016seriously trump 70yearold man know betterfeatured image via screen cap
#
# TRUE: Fake	PREDICTED: Fake
# ----------------------------------------------------------------------------------------------------
#
# ORIGINAL TEXT:
#
# washington reuters  republican senator pat roberts said tuesday “it would appear” vote latest bill repeal affordable care act senate majority leader
# mitch mcconnell cosponsors senators lindsey graham bill cassidy decided enough votes pass it roberts told reporters republicans would target
# healthcare “in form” later current legislative session
#
# TRUE: Real	PREDICTED: Real
# ----------------------------------------------------------------------------------------------------
#
# ORIGINAL TEXT:
#
# approximately one year ago business partner sent screen shot list phony trusted websites going around facebook website 100percentfedupcom along
# several conservative websites like breitbart ij review infowars biz pac review blaze included list websites listed considerable amount traffic
# cumulatively reach hundreds millions readers told ignore it clearly created leftist organization trying discredit conservative websites one year later
# list striking similarities revived time however list amended include one liberal website occupy democrats new author melissa zimdars all list 90 phony
# misleading websites legitimate least one liberal site rightwhile websites list fake called such way legitimate conservative sites list work hard vet
# sources bring readers truthful news find mainstream media election results came in many left inconsolable lashing conservative news sites reason
# hillary lost take long left realize finally met match driven conservatives going roll let left drive narrative time around thus list leftist activist
# melissa zimdars used discredit many us take jobs seriously fight back biased media complexwe curious melissa political leanings could list anything
# wanting pay back sites helped topple hillary little research melissa found twitter account lockdown found slightly ironic considering appears
# transparency thanks way back time machine able find little bit melissamelissa follower radical chicago rising end protest describes group new playbook
# revolution micah white cocreator occupy wall street melissa big fan black lives matter helping promote blm march threatened safety security many
# innocent people chicagohere real reason zimdar likely twitter account lockdown want let everyone know published list conservative sites suggests never
# trusted allow hatred donald trump exposed time besides hatred trump karl rove see below apparently gets goosebumps hears bernie sanders name know
# thinking sounding objective time rightmelissa retweeted hillary angry tweet trumpshe fan dr ben carson belief government able force employers pay
# arbitrary minimum wagemelissa story became popular posted facebook page come surprise given friends actively suggesting names conservative sites
# detest melissa needs add list even though breitbart list  zimdar friend asks her brietbart friends want know submit conservative sites added listand
# course kind conservative media hit list would complete without fox news friend suggests needs put fox news top listthis hillary supporter tells zimdar
# like use list teaching tool classjust another liberal agitator plans use list teach students honest journalismhere zimdar admitting every site always
# unreliable some waffle back forth  heck leave anyhow
#
# TRUE: Fake	PREDICTED: Fake
# ----------------------------------------------------------------------------------------------------
#
# ORIGINAL TEXT:
#
# beijing reuters  china defended ally pakistan tuesday us president donald trump said united states could longer silent pakistan’s “safe havens”
# militants warned much lose continuing “harbor terrorists” trump monday committed united states openended conflict afghanistan signaling would dispatch
# troops america’s longest war vowing “a fight win” trump insisted others  afghan government pakistan india nato allies  step commitment resolving
# 16year conflict saved sharpest words pakistan senior us officials warned security assistance pakistan could reduced unless nucleararmed nation
# cooperated preventing militants using safe havens soil critics say pakistan sees militants taliban useful tools limit influence old rival india
# pakistan denies allowing militants refuge territory saying takes action groups asked trump’s speech chinese foreign ministry spokeswoman hua chunying
# said pakistan front line struggle terrorism made “great sacrifices” “important contributions” fight “we believe international community fully
# recognize pakistan’s antiterrorism” told daily news briefing “we happy see pakistan united states carry antiterror cooperation basis mutual respect
# work together security stability region world” china pakistan consider “allweather friends” close diplomatic economic security ties china security
# concerns region particular links militants pakistan afghanistan islamist groups china blames violence far western region xinjiang “we hope relevant us
# policies help promote security stability development afghanistan region” hua said
#
# TRUE: Real	PREDICTED: Real
# ----------------------------------------------------------------------------------------------------
#
# ORIGINAL TEXT:
#
# london reuters  us secretary defense ash carter said tuesday defense relationship philippines “strong” “longstanding” one asked philippines’
# president’s insult toward us president barack obama carter speaking reporters landing london also described philippines’ new defense minister delfin
# lorenzana someone “very knowledgeable things together” president rodrigo duterte called obama “son bitch” said would lectured extrajudicial killings
# philippines’ drug war duterte later voiced regret language two scheduled meet sidelines asean summit laos obama canceled meeting
#
# TRUE: Real	PREDICTED: Real
# ----------------------------------------------------------------------------------------------------
